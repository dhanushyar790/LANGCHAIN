# %%
import sys
print(sys.executable)
# Out:
# C:\Users\dhanu\anaconda3_new\envs\rag\python.exe

# %%
import sys
# !{sys.executable} -m pip install -U langchain langchain-core langchain-openai langchain-community langchain-text-splitters langchain-huggingface
# Out:
# Requirement already satisfied: langchain in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (1.3.7)
# Requirement already satisfied: langchain-core in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (1.4.6)
# Requirement already satisfied: langchain-openai in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (1.3.0)
# Requirement already satisfied: langchain-community in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (0.4.2)
# Requirement already satisfied: langchain-text-splitters in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-huggingface in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (1.2.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.4 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-core) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-core) (0.8.14)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-core) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-core) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.4->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (4.13.0)
# Requirement already satisfied: certifi in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-openai) (2.41.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.15.0)
# Requirement already satisfied: sniffio in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.68.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (1.3.1)
# Requirement already satisfied: regex in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.5.9)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-community) (2.0.50)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.7.0)
# Requirement already satisfied: greenlet>=1 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.1)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-huggingface) (1.19.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: click>=8.4.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.29.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.25.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.0.4)
# Requirement already satisfied: colorama in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dhanu\anaconda3_new\envs\rag\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.1.2)

# %%
import warnings
warnings.filterwarnings("ignore")

from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

print("All imports successful!")
# Out:
# All imports successful!
